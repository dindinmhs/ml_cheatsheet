# %% [markdown]
# **0. Import Dependencies**

# %%
import mediapipe as mp
import cv2

# %%
mp_drawing = mp.solutions.drawing_utils
mp_holistic = mp.solutions.holistic
mp_face_mesh = mp.solutions.face_mesh

# %% [markdown]
# **1. Make Some detection**

# %%
cap = cv2.VideoCapture(0)
# Initiate holistic model
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    
    while cap.isOpened():
        ret, frame = cap.read()
        
        # Recolor Feed
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False        
        
        # Make Detections
        results = holistic.process(image)
        # print(results.face_landmarks)
        
        # face_landmarks, pose_landmarks, left_hand_landmarks, right_hand_landmarks
        
        # Recolor image back to BGR for rendering
        image.flags.writeable = True   
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
        
        # 1. Draw face landmarks
        mp_drawing.draw_landmarks(image, results.face_landmarks, mp_face_mesh.FACEMESH_TESSELATION, 
                                 mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1),
                                 mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
                                 )
        
        # 2. Right hand
        mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
                                 )

        # 3. Left Hand
        mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                                 )

        # 4. Pose Detections
        mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                                 )
                        
        cv2.imshow('Raw Webcam Feed', image)

        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# **2. Capture landmarks & export to csv**
# <br>
# ![landmark](https://camo.githubusercontent.com/d3afebfc801ee1a094c28604c7a0eb25f8b9c9925f75b0fff4c8c8b4871c0d28/68747470733a2f2f6d65646961706970652e6465762f696d616765732f6d6f62696c652f706f73655f747261636b696e675f66756c6c5f626f64795f6c616e646d61726b732e706e67)

# %%
import csv
import os
import numpy as np

# %%
num_coords = len(results.pose_landmarks.landmark)+len(results.face_landmarks.landmark)
num_coords
# Out:
# 501

# %%
landmarks = ['class']
for val in range(1, num_coords+1):
    landmarks += ['x{}'.format(val), 'y{}'.format(val), 'z{}'.format(val), 'v{}'.format(val)]
landmarks
# Out:
# ['class',
#  'x1',
#  'y1',
#  'z1',
#  'v1',
#  'x2',
#  'y2',
#  'z2',
#  'v2',
#  'x3',
#  'y3',
#  'z3',
#  'v3',
#  'x4',
#  'y4',
#  'z4',
#  'v4',
#  'x5',
#  'y5',
#  'z5',
#  'v5',
#  'x6',
#  'y6',
#  'z6',
#  'v6',
#  'x7',
#  'y7',
#  'z7',
#  'v7',
#  'x8',
#  'y8',
#  'z8',
#  'v8',
#  'x9',
#  'y9',
#  'z9',
#  'v9',
#  'x10',
#  'y10',
#  'z10',
#  'v10',
#  'x11',
#  'y11',
#  'z11',
#  'v11',
#  'x12',
#  'y12',
#  'z12',
#  'v12',
#  'x13',
#  'y13',
#  'z13',
#  'v13',
#  'x14',
#  'y14',
#  'z14',
#  'v14',
#  'x15',
#  'y15',
#  'z15',
#  'v15',
#  'x16',
#  'y16',
#  'z16',
#  'v16',
#  'x17',
#  'y17',
#  'z17',
#  'v17',
#  'x18',
#  'y18',
#  'z18',
#  'v18',
#  'x19',
#  'y19',
#  'z19',
#  'v19',
#  'x20',
#  'y20',
#  'z20',
#  'v20',
#  'x21',
#  'y21',
#  'z21',
#  'v21',
#  'x22',
#  'y22',
#  'z22',
#  'v22',
#  'x23',
#  'y23',
#  'z23',
#  'v23',
#  'x24',
#  'y24',
#  'z24',
#  'v24',
#  'x25',
#  'y25',
#  'z25',
#  'v25',
#  'x26',
#  'y26',
#  'z26',
#  'v26',
#  'x27',
#  'y27',
#  'z27',
#  'v27',
#  'x28',
#  'y28',
#  'z28',
#  'v28',
#  'x29',
#  'y29',
#  'z29',
#  'v29',
#  'x30',
#  'y30',
#  'z30',
#  'v30',
#  'x31',
#  'y31',
#  'z31',
#  'v31',
#  'x32',
#  'y32',
#  'z32',
#  'v32',
#  'x33',
#  'y33',
#  'z33',
#  'v33',
#  'x34',
#  'y34',
#  'z34',
#  'v34',
#  'x35',
#  'y35',
#  'z35',
#  'v35',
#  'x36',
#  'y36',
#  'z36',
#  'v36',
#  'x37',
#  'y37',
#  'z37',
#  'v37',
#  'x38',
#  'y38',
#  'z38',
#  'v38',
#  'x39',
#  'y39',
#  'z39',
#  'v39',
#  'x40',
#  'y40',
#  'z40',
#  'v40',
#  'x41',
#  'y41',
#  'z41',
#  'v41',
#  'x42',
#  'y42',
#  'z42',
#  'v42',
#  'x43',
#  'y43',
#  'z43',
#  'v43',
#  'x44',
#  'y44',
#  'z44',
#  'v44',
#  'x45',
#  'y45',
#  'z45',
#  'v45',
#  'x46',
#  'y46',
#  'z46',
#  'v46',
#  'x47',
#  'y47',
#  'z47',
#  'v47',
#  'x48',
#  'y48',
#  'z48',
#  'v48',
#  'x49',
#  'y49',
#  'z49',
#  'v49',
#  'x50',
#  'y50',
#  'z50',
#  'v50',
#  'x51',
#  'y51',
#  'z51',
#  'v51',
#  'x52',
#  'y52',
#  'z52',
#  'v52',
#  'x53',
#  'y53',
#  'z53',
#  'v53',
#  'x54',
#  'y54',
#  'z54',
#  'v54',
#  'x55',
#  'y55',
#  'z55',
#  'v55',
#  'x56',
#  'y56',
#  'z56',
#  'v56',
#  'x57',
#  'y57',
#  'z57',
#  'v57',
#  'x58',
#  'y58',
#  'z58',
#  'v58',
#  'x59',
#  'y59',
#  'z59',
#  'v59',
#  'x60',
#  'y60',
#  'z60',
#  'v60',
#  'x61',
#  'y61',
#  'z61',
#  'v61',
#  'x62',
#  'y62',
#  'z62',
#  'v62',
#  'x63',
#  'y63',
#  'z63',
#  'v63',
#  'x64',
#  'y64',
#  'z64',
#  'v64',
#  'x65',
#  'y65',
#  'z65',
#  'v65',
#  'x66',
#  'y66',
#  'z66',
#  'v66',
#  'x67',
#  'y67',
#  'z67',
#  'v67',
#  'x68',
#  'y68',
#  'z68',
#  'v68',
#  'x69',
#  'y69',
#  'z69',
#  'v69',
#  'x70',
#  'y70',
#  'z70',
#  'v70',
#  'x71',
#  'y71',
#  'z71',
#  'v71',
#  'x72',
#  'y72',
#  'z72',
#  'v72',
#  'x73',
#  'y73',
#  'z73',
#  'v73',
#  'x74',
#  'y74',
#  'z74',
#  'v74',
#  'x75',
#  'y75',
#  'z75',
#  'v75',
#  'x76',
#  'y76',
#  'z76',
#  'v76',
#  'x77',
#  'y77',
#  'z77',
#  'v77',
#  'x78',
#  'y78',
#  'z78',
#  'v78',
#  'x79',
#  'y79',
#  'z79',
#  'v79',
#  'x80',
#  'y80',
#  'z80',
#  'v80',
#  'x81',
#  'y81',
#  'z81',
#  'v81',
#  'x82',
#  'y82',
#  'z82',
#  'v82',
#  'x83',
#  'y83',
#  'z83',
#  'v83',
#  'x84',
#  'y84',
#  'z84',
#  'v84',
#  'x85',
#  'y85',
#  'z85',
#  'v85',
#  'x86',
#  'y86',
#  'z86',
#  'v86',
#  'x87',
#  'y87',
#  'z87',
#  'v87',
#  'x88',
#  'y88',
#  'z88',
#  'v88',
#  'x89',
#  'y89',
#  'z89',
#  'v89',
#  'x90',
#  'y90',
#  'z90',
#  'v90',
#  'x91',
#  'y91',
#  'z91',
#  'v91',
#  'x92',
#  'y92',
#  'z92',
#  'v92',
#  'x93',
#  'y93',
#  'z93',
#  'v93',
#  'x94',
#  'y94',
#  'z94',
#  'v94',
#  'x95',
#  'y95',
#  'z95',
#  'v95',
#  'x96',
#  'y96',
#  'z96',
#  'v96',
#  'x97',
#  'y97',
#  'z97',
#  'v97',
#  'x98',
#  'y98',
#  'z98',
#  'v98',
#  'x99',
#  'y99',
#  'z99',
#  'v99',
#  'x100',
#  'y100',
#  'z100',
#  'v100',
#  'x101',
#  'y101',
#  'z101',
#  'v101',
#  'x102',
#  'y102',
#  'z102',
#  'v102',
#  'x103',
#  'y103',
#  'z103',
#  'v103',
#  'x104',
#  'y104',
#  'z104',
#  'v104',
#  'x105',
#  'y105',
#  'z105',
#  'v105',
#  'x106',
#  'y106',
#  'z106',
#  'v106',
#  'x107',
#  'y107',
#  'z107',
#  'v107',
#  'x108',
#  'y108',
#  'z108',
#  'v108',
#  'x109',
#  'y109',
#  'z109',
#  'v109',
#  'x110',
#  'y110',
#  'z110',
#  'v110',
#  'x111',
#  'y111',
#  'z111',
#  'v111',
#  'x112',
#  'y112',
#  'z112',
#  'v112',
#  'x113',
#  'y113',
#  'z113',
#  'v113',
#  'x114',
#  'y114',
#  'z114',
#  'v114',
#  'x115',
#  'y115',
#  'z115',
#  'v115',
#  'x116',
#  'y116',
#  'z116',
#  'v116',
#  'x117',
#  'y117',
#  'z117',
#  'v117',
#  'x118',
#  'y118',
#  'z118',
#  'v118',
#  'x119',
#  'y119',
#  'z119',
#  'v119',
#  'x120',
#  'y120',
#  'z120',
#  'v120',
#  'x121',
#  'y121',
#  'z121',
#  'v121',
#  'x122',
#  'y122',
#  'z122',
#  'v122',
#  'x123',
#  'y123',
#  'z123',
#  'v123',
#  'x124',
#  'y124',
#  'z124',
#  'v124',
#  'x125',
#  'y125',
#  'z125',
#  'v125',
#  'x126',
#  'y126',
#  'z126',
#  'v126',
#  'x127',
#  'y127',
#  'z127',
#  'v127',
#  'x128',
#  'y128',
#  'z128',
#  'v128',
#  'x129',
#  'y129',
#  'z129',
#  'v129',
#  'x130',
#  'y130',
#  'z130',
#  'v130',
#  'x131',
#  'y131',
#  'z131',
#  'v131',
#  'x132',
#  'y132',
#  'z132',
#  'v132',
#  'x133',
#  'y133',
#  'z133',
#  'v133',
#  'x134',
#  'y134',
#  'z134',
#  'v134',
#  'x135',
#  'y135',
#  'z135',
#  'v135',
#  'x136',
#  'y136',
#  'z136',
#  'v136',
#  'x137',
#  'y137',
#  'z137',
#  'v137',
#  'x138',
#  'y138',
#  'z138',
#  'v138',
#  'x139',
#  'y139',
#  'z139',
#  'v139',
#  'x140',
#  'y140',
#  'z140',
#  'v140',
#  'x141',
#  'y141',
#  'z141',
#  'v141',
#  'x142',
#  'y142',
#  'z142',
#  'v142',
#  'x143',
#  'y143',
#  'z143',
#  'v143',
#  'x144',
#  'y144',
#  'z144',
#  'v144',
#  'x145',
#  'y145',
#  'z145',
#  'v145',
#  'x146',
#  'y146',
#  'z146',
#  'v146',
#  'x147',
#  'y147',
#  'z147',
#  'v147',
#  'x148',
#  'y148',
#  'z148',
#  'v148',
#  'x149',
#  'y149',
#  'z149',
#  'v149',
#  'x150',
#  'y150',
#  'z150',
#  'v150',
#  'x151',
#  'y151',
#  'z151',
#  'v151',
#  'x152',
#  'y152',
#  'z152',
#  'v152',
#  'x153',
#  'y153',
#  'z153',
#  'v153',
#  'x154',
#  'y154',
#  'z154',
#  'v154',
#  'x155',
#  'y155',
#  'z155',
#  'v155',
#  'x156',
#  'y156',
#  'z156',
#  'v156',
#  'x157',
#  'y157',
#  'z157',
#  'v157',
#  'x158',
#  'y158',
#  'z158',
#  'v158',
#  'x159',
#  'y159',
#  'z159',
#  'v159',
#  'x160',
#  'y160',
#  'z160',
#  'v160',
#  'x161',
#  'y161',
#  'z161',
#  'v161',
#  'x162',
#  'y162',
#  'z162',
#  'v162',
#  'x163',
#  'y163',
#  'z163',
#  'v163',
#  'x164',
#  'y164',
#  'z164',
#  'v164',
#  'x165',
#  'y165',
#  'z165',
#  'v165',
#  'x166',
#  'y166',
#  'z166',
#  'v166',
#  'x167',
#  'y167',
#  'z167',
#  'v167',
#  'x168',
#  'y168',
#  'z168',
#  'v168',
#  'x169',
#  'y169',
#  'z169',
#  'v169',
#  'x170',
#  'y170',
#  'z170',
#  'v170',
#  'x171',
#  'y171',
#  'z171',
#  'v171',
#  'x172',
#  'y172',
#  'z172',
#  'v172',
#  'x173',
#  'y173',
#  'z173',
#  'v173',
#  'x174',
#  'y174',
#  'z174',
#  'v174',
#  'x175',
#  'y175',
#  'z175',
#  'v175',
#  'x176',
#  'y176',
#  'z176',
#  'v176',
#  'x177',
#  'y177',
#  'z177',
#  'v177',
#  'x178',
#  'y178',
#  'z178',
#  'v178',
#  'x179',
#  'y179',
#  'z179',
#  'v179',
#  'x180',
#  'y180',
#  'z180',
#  'v180',
#  'x181',
#  'y181',
#  'z181',
#  'v181',
#  'x182',
#  'y182',
#  'z182',
#  'v182',
#  'x183',
#  'y183',
#  'z183',
#  'v183',
#  'x184',
#  'y184',
#  'z184',
#  'v184',
#  'x185',
#  'y185',
#  'z185',
#  'v185',
#  'x186',
#  'y186',
#  'z186',
#  'v186',
#  'x187',
#  'y187',
#  'z187',
#  'v187',
#  'x188',
#  'y188',
#  'z188',
#  'v188',
#  'x189',
#  'y189',
#  'z189',
#  'v189',
#  'x190',
#  'y190',
#  'z190',
#  'v190',
#  'x191',
#  'y191',
#  'z191',
#  'v191',
#  'x192',
#  'y192',
#  'z192',
#  'v192',
#  'x193',
#  'y193',
#  'z193',
#  'v193',
#  'x194',
#  'y194',
#  'z194',
#  'v194',
#  'x195',
#  'y195',
#  'z195',
#  'v195',
#  'x196',
#  'y196',
#  'z196',
#  'v196',
#  'x197',
#  'y197',
#  'z197',
#  'v197',
#  'x198',
#  'y198',
#  'z198',
#  'v198',
#  'x199',
#  'y199',
#  'z199',
#  'v199',
#  'x200',
#  'y200',
#  'z200',
#  'v200',
#  'x201',
#  'y201',
#  'z201',
#  'v201',
#  'x202',
#  'y202',
#  'z202',
#  'v202',
#  'x203',
#  'y203',
#  'z203',
#  'v203',
#  'x204',
#  'y204',
#  'z204',
#  'v204',
#  'x205',
#  'y205',
#  'z205',
#  'v205',
#  'x206',
#  'y206',
#  'z206',
#  'v206',
#  'x207',
#  'y207',
#  'z207',
#  'v207',
#  'x208',
#  'y208',
#  'z208',
#  'v208',
#  'x209',
#  'y209',
#  'z209',
#  'v209',
#  'x210',
#  'y210',
#  'z210',
#  'v210',
#  'x211',
#  'y211',
#  'z211',
#  'v211',
#  'x212',
#  'y212',
#  'z212',
#  'v212',
#  'x213',
#  'y213',
#  'z213',
#  'v213',
#  'x214',
#  'y214',
#  'z214',
#  'v214',
#  'x215',
#  'y215',
#  'z215',
#  'v215',
#  'x216',
#  'y216',
#  'z216',
#  'v216',
#  'x217',
#  'y217',
#  'z217',
#  'v217',
#  'x218',
#  'y218',
#  'z218',
#  'v218',
#  'x219',
#  'y219',
#  'z219',
#  'v219',
#  'x220',
#  'y220',
#  'z220',
#  'v220',
#  'x221',
#  'y221',
#  'z221',
#  'v221',
#  'x222',
#  'y222',
#  'z222',
#  'v222',
#  'x223',
#  'y223',
#  'z223',
#  'v223',
#  'x224',
#  'y224',
#  'z224',
#  'v224',
#  'x225',
#  'y225',
#  'z225',
#  'v225',
#  'x226',
#  'y226',
#  'z226',
#  'v226',
#  'x227',
#  'y227',
#  'z227',
#  'v227',
#  'x228',
#  'y228',
#  'z228',
#  'v228',
#  'x229',
#  'y229',
#  'z229',
#  'v229',
#  'x230',
#  'y230',
#  'z230',
#  'v230',
#  'x231',
#  'y231',
#  'z231',
#  'v231',
#  'x232',
#  'y232',
#  'z232',
#  'v232',
#  'x233',
#  'y233',
#  'z233',
#  'v233',
#  'x234',
#  'y234',
#  'z234',
#  'v234',
#  'x235',
#  'y235',
#  'z235',
#  'v235',
#  'x236',
#  'y236',
#  'z236',
#  'v236',
#  'x237',
#  'y237',
#  'z237',
#  'v237',
#  'x238',
#  'y238',
#  'z238',
#  'v238',
#  'x239',
#  'y239',
#  'z239',
#  'v239',
#  'x240',
#  'y240',
#  'z240',
#  'v240',
#  'x241',
#  'y241',
#  'z241',
#  'v241',
#  'x242',
#  'y242',
#  'z242',
#  'v242',
#  'x243',
#  'y243',
#  'z243',
#  'v243',
#  'x244',
#  'y244',
#  'z244',
#  'v244',
#  'x245',
#  'y245',
#  'z245',
#  'v245',
#  'x246',
#  'y246',
#  'z246',
#  'v246',
#  'x247',
#  'y247',
#  'z247',
#  'v247',
#  'x248',
#  'y248',
#  'z248',
#  'v248',
#  'x249',
#  'y249',
#  'z249',
#  'v249',
#  'x250',
#  'y250',
#  'z250',
#  ...]

# %%
with open('coords.csv', mode='w', newline='') as f:
    csv_writer = csv.writer(f, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
    csv_writer.writerow(landmarks)

# %%
class_name = "uppercut"

# %%
import cv2
import mediapipe as mp
import numpy as np
import csv
import time  # Import library untuk timer

mp_holistic = mp.solutions.holistic
mp_drawing = mp.solutions.drawing_utils

cap = cv2.VideoCapture(0)

start_time = time.time()  # Catat waktu mulai
DURATION = 30  # Durasi dalam detik

# Initiate holistic model
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    while cap.isOpened():
        current_time = time.time()
        if current_time - start_time > DURATION:
            break  # Hentikan setelah durasi tertentu

        ret, frame = cap.read()
        
        # Recolor Feed
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False        
        
        # Make Detections
        results = holistic.process(image)
        
        # Recolor image back to BGR for rendering
        image.flags.writeable = True   
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
        
        # 1. Draw face landmarks
        mp_drawing.draw_landmarks(image, results.face_landmarks, mp_face_mesh.FACEMESH_TESSELATION, 
                                 mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1),
                                 mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
                                 )
        
        # 2. Right hand
        mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
                                 )

        # 3. Left Hand
        mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                                 )

        # 4. Pose Detections
        mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                                 )

        # Export coordinates
        try:
            pose = results.pose_landmarks.landmark
            pose_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in pose]).flatten())
            face = results.face_landmarks.landmark
            face_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in face]).flatten())
            row = pose_row + face_row
            row.insert(0, class_name)  

            with open('coords.csv', mode='a', newline='') as f:
                csv_writer = csv.writer(f, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
                csv_writer.writerow(row)

        except:
            pass

        cv2.imshow('Raw Webcam Feed', image)

        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# **3. Train Model**

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('coords.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 466 entries, 0 to 465
# Columns: 2005 entries, class to v501
# dtypes: float64(2004), object(1)
# memory usage: 7.1+ MB

# %%
X = df.drop('class', axis=1)
y = df["class"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1234)
X_test
# Out:
#            x1        y1        z1        v1  ...      x501      y501      z501  v501
# 417  0.407529  0.347876 -0.516542  0.999731  ...  0.452853  0.288874  0.000277   0.0
# 100  0.563965  0.364720 -0.238128  0.999461  ...  0.604537  0.295823 -0.015018   0.0
# 287  0.461323  0.325902 -0.309484  0.999820  ...  0.500483  0.272929  0.016873   0.0
# 123  0.480422  0.229977 -0.382293  0.999852  ...  0.531917  0.174185  0.014092   0.0
# 194  0.472223  0.332923 -0.324701  0.999931  ...  0.511750  0.292980  0.006063   0.0
# ..        ...       ...       ...       ...  ...       ...       ...       ...   ...
# 433  0.539306  0.285815 -0.415998  0.999917  ...  0.585990  0.222420 -0.012164   0.0
# 99   0.568896  0.363155 -0.243305  0.999516  ...  0.609497  0.294719 -0.013116   0.0
# 384  0.467860  0.360074 -0.469062  0.998018  ...  0.494577  0.300878  0.016207   0.0
# 405  0.402061  0.357254 -0.383813  0.999684  ...  0.438307  0.302504  0.009826   0.0
# 166  0.291797  0.349719 -0.313474  0.999447  ...  0.360031  0.313493  0.024903   0.0
#
# [140 rows x 2004 columns]

# %%
from sklearn.pipeline import make_pipeline 
from sklearn.preprocessing import StandardScaler 

from sklearn.linear_model import LogisticRegression, RidgeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier

# %%
pipelines = {
    'lr': make_pipeline(StandardScaler(), LogisticRegression(max_iter=1000, solver='saga')),
    'rc': make_pipeline(StandardScaler(), RidgeClassifier(alpha=1.0)),
    'rf': make_pipeline(StandardScaler(), RandomForestClassifier(n_estimators=200, max_features='sqrt')),
    'gb': make_pipeline(StandardScaler(), GradientBoostingClassifier(n_estimators=200, learning_rate=0.1, max_features='sqrt', subsample=0.8)),
}

# %%
fit_models = {}
for algo, pipeline in pipelines.items():
    model = pipeline.fit(X_train, y_train)
    fit_models[algo] = model
# Out:
# c:\Users\lenovo\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
from sklearn.metrics import accuracy_score 
import pickle

# %%
for algo, model in fit_models.items():
    yhat = model.predict(X_test)
    print(algo, accuracy_score(y_test, yhat))
# Out:
# lr 1.0
# rc 1.0
# rf 0.9928571428571429
# gb 0.9857142857142858

# %%
fit_models['rc'].predict(X_test)
# Out:
# array(['uppercut', 'jab', 'uppercut', 'jab', 'jab', 'jab', 'jab', 'cross',
#        'block', 'cross', 'jab', 'jab', 'cross', 'cross', 'uppercut',
#        'cross', 'uppercut', 'cross', 'uppercut', 'uppercut', 'jab', 'jab',
#        'uppercut', 'jab', 'jab', 'uppercut', 'uppercut', 'cross', 'cross',
#        'cross', 'cross', 'jab', 'uppercut', 'block', 'uppercut',
#        'uppercut', 'uppercut', 'jab', 'jab', 'jab', 'uppercut',
#        'uppercut', 'uppercut', 'uppercut', 'uppercut', 'uppercut', 'jab',
#        'jab', 'uppercut', 'cross', 'uppercut', 'jab', 'uppercut', 'block',
#        'uppercut', 'uppercut', 'cross', 'cross', 'jab', 'jab', 'jab',
#        'uppercut', 'uppercut', 'uppercut', 'uppercut', 'cross', 'jab',
#        'cross', 'uppercut', 'cross', 'block', 'jab', 'jab', 'uppercut',
#        'jab', 'uppercut', 'jab', 'jab', 'uppercut', 'cross', 'uppercut',
#        'uppercut', 'uppercut', 'block', 'uppercut', 'jab', 'jab', 'jab',
#        'cross', 'uppercut', 'uppercut', 'uppercut', 'jab', 'uppercut',
#        'block', 'jab', 'cross', 'jab', 'uppercut', 'cross', 'jab',
#        'uppercut', 'jab', 'uppercut', 'uppercut', 'jab', 'cross',
#        'uppercut', 'uppercut', 'uppercut', 'jab', 'jab', 'uppercut',
#        'uppercut', 'uppercut', 'uppercut', 'jab', 'uppercut', 'jab',
#        'uppercut', 'uppercut', 'cross', 'jab', 'jab', 'uppercut', 'cross',
#        'uppercut', 'jab', 'cross', 'jab', 'jab', 'uppercut', 'uppercut',
#        'cross', 'jab', 'uppercut', 'jab', 'uppercut', 'uppercut', 'jab'],
#       dtype='<U8')

# %%
with open('pose_detection.pkl', 'wb') as f:
    pickle.dump(fit_models['rc'], f)

# %%
with open('pose_detection.pkl', 'rb') as f:
    model = pickle.load(f)
model
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('ridgeclassifier', RidgeClassifier())])

# %%
cap = cv2.VideoCapture(0)
# Initiate holistic model
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    
    while cap.isOpened():
        ret, frame = cap.read()
        
        # Recolor Feed
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False        
        
        # Make Detections
        results = holistic.process(image)
        # print(results.face_landmarks)
        
        # face_landmarks, pose_landmarks, left_hand_landmarks, right_hand_landmarks
        
        # Recolor image back to BGR for rendering
        image.flags.writeable = True   
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
        
        # 1. Draw face landmarks
        mp_drawing.draw_landmarks(image, results.face_landmarks, mp_face_mesh.FACEMESH_TESSELATION, 
                                 mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1),
                                 mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
                                 )
        
        # 2. Right hand
        mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
                                 )

        # 3. Left Hand
        mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                                 )

        # 4. Pose Detections
        mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                                 )
        # Export coordinates
        try:
            # Extract Pose landmarks
            pose = results.pose_landmarks.landmark
            pose_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in pose]).flatten())
            
            # Extract Face landmarks
            face = results.face_landmarks.landmark
            face_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in face]).flatten())
            
            # Concate rows
            row = pose_row+face_row
            
#             # Append class name 
#             row.insert(0, class_name)
            
#             # Export to CSV
#             with open('coords.csv', mode='a', newline='') as f:
#                 csv_writer = csv.writer(f, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
#                 csv_writer.writerow(row) 

            # Make Detections
            X = pd.DataFrame([row], columns=landmarks[1:])
            body_language_class = model.predict(X)[0]
            body_language_prob = model.decision_function(X)
            print(body_language_class, body_language_prob)
            
            # Grab ear coords
            coords = tuple(np.multiply(
                            np.array(
                                (results.pose_landmarks.landmark[mp_holistic.PoseLandmark.LEFT_EAR].x, 
                                 results.pose_landmarks.landmark[mp_holistic.PoseLandmark.LEFT_EAR].y))
                        , [640,480]).astype(int))
            
            cv2.rectangle(image, 
                          (coords[0], coords[1]+5), 
                          (coords[0]+len(body_language_class)*20, coords[1]-30), 
                          (245, 117, 16), -1)
            cv2.putText(image, body_language_class, coords, 
                        cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
            
            # Get status box
            cv2.rectangle(image, (0,0), (250, 60), (245, 117, 16), -1)
            
            # Display Class
            cv2.putText(image, 'CLASS'
                        , (95,12), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 0), 1, cv2.LINE_AA)
            cv2.putText(image, body_language_class.split(' ')[0]
                        , (90,40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
            
            # Display Probability
            cv2.putText(image, 'PROB'
                        , (15,12), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 0), 1, cv2.LINE_AA)
            cv2.putText(image, str(round(body_language_prob[np.argmax(body_language_prob)],2))
                        , (10,40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
            
        except Exception as e:
            print(f"Terjadi error: {e}")
            pass
                        
        cv2.imshow('Raw Webcam Feed', image)

        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()
# Out:
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# block [[ 13.90671094  12.48640027 -14.32331223 -14.06979899]]
# Terjadi error: type numpy.ndarray doesn't define __round__ method
# block [[ 12.73864631  11.9961427  -13.62363023 -13.11115878]]
# Terjadi error: type numpy.ndarray doesn't define __round__ method
# block [[ 13.64842761  11.22148135 -13.440557   -13.42935196]]
# Terjadi error: type numpy.ndarray doesn't define __round__ method
# block [[ 13.43795743  10.71110265 -13.1528766  -12.99618348]]
# Terjadi error: type numpy.ndarray doesn't define __round__ method
# block [[ 14.26634669  11.26010191 -14.20046264 -13.32598597]]
# Terjadi error: type numpy.ndarray doesn't define __round__ method
# block [[ 16.00095398  11.74971627 -14.67822178 -15.07244847]]
# Terjadi error: type numpy.ndarray doesn't define __round__ method
# block [[ 18.02803887  10.72653279 -15.19102788 -15.56354378]]
# Terjadi error: type numpy.ndarray doesn't define __round__ method
# block [[ 19.15936617  11.39227592 -15.9033791  -16.648263  ]]
# Terjadi error: type numpy.ndarray doesn't define __round__ method
# block [[ 18.41675658  11.53815873 -15.78699344 -16.16792187]]
# Terjadi error: type numpy.ndarray doesn't define __round__ method
# block [[ 17.95585644  11.63350665 -15.5316051  -16.05775799]]
# Terjadi error: type numpy.ndarray doesn't define __round__ method
# block [[ 18.3152844   11.21872522 -15.1913257  -16.34268393]]
# Terjadi error: type numpy.ndarray doesn't define __round__ method
# block [[ 18.56825196  11.08417425 -15.86273686 -15.78968935]]
# Terjadi error: type numpy.ndarray doesn't define __round__ method
# block [[ 19.71034449  11.31751258 -16.14271574 -16.88514133]]
# Terjadi error: type numpy.ndarray doesn't define __round__ method
# block [[ 20.57772476  11.68551021 -16.57070541 -17.69252956]]
# Terjadi error: type numpy.ndarray doesn't define __round__ method
# block [[ 20.03323644  11.64100959 -15.95481875 -17.71942728]]
# Terjadi error: type numpy.ndarray doesn't define __round__ method
# block [[ 19.90103599  11.88532455 -16.00683605 -17.77952448]]
# Terjadi error: type numpy.ndarray doesn't define __round__ method
# block [[ 19.36031456  11.90491421 -15.97454206 -17.29068671]]
# Terjadi error: type numpy.ndarray doesn't define __round__ method
# block [[ 19.63239102  11.77022189 -15.79332877 -17.60928414]]
# Terjadi error: type numpy.ndarray doesn't define __round__ method
# block [[ 19.31290748  11.69552829 -15.42012759 -17.58830818]]
# Terjadi error: type numpy.ndarray doesn't define __round__ method
# block [[ 21.38325856  11.66327654 -16.15572774 -18.89080737]]
# Terjadi error: type numpy.ndarray doesn't define __round__ method
# block [[ 22.66490903  11.61524056 -16.50971825 -19.77043134]]
# Terjadi error: type numpy.ndarray doesn't define __round__ method
# block [[ 25.55327369  11.63506635 -17.15576838 -22.03257166]]
# Terjadi error: type numpy.ndarray doesn't define __round__ method
# block [[ 24.72372675  11.44351386 -16.50256969 -21.66467093]]
# Terjadi error: type numpy.ndarray doesn't define __round__ method
# block [[ 25.48340857  11.23076236 -17.0997694  -21.61440153]]
# Terjadi error: type numpy.ndarray doesn't define __round__ method
# block [[ 27.13771519  11.37471669 -17.55495914 -22.95747274]]
# Terjadi error: type numpy.ndarray doesn't define __round__ method
# block [[ 26.43340214  11.68964883 -17.50559287 -22.6174581 ]]
# Terjadi error: type numpy.ndarray doesn't define __round__ method
# block [[ 28.65528097  11.60573757 -18.42293498 -23.83808356]]
# Terjadi error: type numpy.ndarray doesn't define __round__ method
# block [[ 27.37161223  11.27122869 -18.41925052 -22.2235904 ]]
# Terjadi error: type numpy.ndarray doesn't define __round__ method
# block [[ 28.71825593  12.13137131 -18.30516319 -24.54446405]]
# Terjadi error: type numpy.ndarray doesn't define __round__ method
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# block [[ 23.69093508   9.8213481  -16.33793858 -19.17434459]]
# Terjadi error: type numpy.ndarray doesn't define __round__ method
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# uppercut [[-0.68784008 -3.30798008  0.16672703  1.82909313]]
# Terjadi error: index 3 is out of bounds for axis 0 with size 1
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# uppercut [[-0.54002035 -4.73354212  1.45940809  1.81415438]]
# Terjadi error: index 3 is out of bounds for axis 0 with size 1
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# jab [[-0.0426359  -3.3608912   1.32266927  0.08085783]]
# Terjadi error: index 2 is out of bounds for axis 0 with size 1
# jab [[ 0.17074709 -2.93612472  0.84374114 -0.0783635 ]]
# Terjadi error: index 2 is out of bounds for axis 0 with size 1
# jab [[-0.0049823  -2.53214028  0.68151873 -0.14439615]]
# Terjadi error: index 2 is out of bounds for axis 0 with size 1
# jab [[-0.03249    -2.1977415   0.32019726 -0.08996577]]
# Terjadi error: index 2 is out of bounds for axis 0 with size 1
# block [[ 0.01104774 -1.8935554  -0.03638997 -0.08110237]]
# Terjadi error: type numpy.ndarray doesn't define __round__ method
# uppercut [[-0.15159202 -1.51556379 -0.27654297 -0.05630122]]
# Terjadi error: index 3 is out of bounds for axis 0 with size 1
# uppercut [[-0.23710404 -1.2598541  -0.51491933  0.01187748]]
# Terjadi error: index 3 is out of bounds for axis 0 with size 1
# uppercut [[-0.37753185 -0.96161948 -0.5283827  -0.13246596]]
# Terjadi error: index 3 is out of bounds for axis 0 with size 1
# uppercut [[-0.26887943 -1.10985622 -0.51989684 -0.10136752]]
# Terjadi error: index 3 is out of bounds for axis 0 with size 1
# block [[ 0.32638656 -1.08579304 -0.36284119 -0.87775233]]
# Terjadi error: type numpy.ndarray doesn't define __round__ method
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# block [[ 0.72291082  0.04579808 -1.58028309 -1.18842581]]
# Terjadi error: type numpy.ndarray doesn't define __round__ method
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# cross [[-0.18861905  0.42107221 -1.52577726 -0.7066759 ]]
# Terjadi error: index 1 is out of bounds for axis 0 with size 1
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# block [[ 0.26010439  0.14661888 -2.20261531 -0.20410797]]
# Terjadi error: type numpy.ndarray doesn't define __round__ method
# block [[ 0.25430727  0.17973548 -2.23250073 -0.20154202]]
# Terjadi error: type numpy.ndarray doesn't define __round__ method
# cross [[ 0.1059685   0.40845642 -2.28863234 -0.22579257]]
# Terjadi error: index 1 is out of bounds for axis 0 with size 1
# cross [[ 0.13186387  0.33544695 -2.33876494 -0.12854588]]
# Terjadi error: index 1 is out of bounds for axis 0 with size 1
# cross [[ 0.25673361  0.32575018 -2.36840235 -0.21408144]]
# Terjadi error: index 1 is out of bounds for axis 0 with size 1
# cross [[ 0.19615048  0.45487046 -2.50728869 -0.14373225]]
# Terjadi error: index 1 is out of bounds for axis 0 with size 1
# cross [[ 0.20833483  0.35597859 -2.41768955 -0.14662386]]
# Terjadi error: index 1 is out of bounds for axis 0 with size 1
# cross [[ 0.0659143   0.6123658  -2.34732898 -0.33095112]]
# Terjadi error: index 1 is out of bounds for axis 0 with size 1
# cross [[ 0.03933071  0.58580001 -2.39426976 -0.23086097]]
# Terjadi error: index 1 is out of bounds for axis 0 with size 1
# cross [[-0.11132217  0.60976004 -2.26573342 -0.23270445]]
# Terjadi error: index 1 is out of bounds for axis 0 with size 1
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# cross [[ 0.00415971  0.47671401 -2.15436352 -0.3265102 ]]
# Terjadi error: index 1 is out of bounds for axis 0 with size 1
# cross [[ 0.04315796  0.53263308 -2.17414843 -0.40164262]]
# Terjadi error: index 1 is out of bounds for axis 0 with size 1
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# cross [[ 0.28346065  0.31358098 -2.15086912 -0.44617251]]
# Terjadi error: index 1 is out of bounds for axis 0 with size 1
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# cross [[ 0.08270888  0.50558026 -2.30077528 -0.28751386]]
# Terjadi error: index 1 is out of bounds for axis 0 with size 1
# cross [[-0.05760733  0.50771328 -2.20683841 -0.24326753]]
# Terjadi error: index 1 is out of bounds for axis 0 with size 1
# cross [[ 0.00895791  0.36553818 -2.23651193 -0.13798416]]
# Terjadi error: index 1 is out of bounds for axis 0 with size 1
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# cross [[-0.55558852  0.6616339  -1.96292081 -0.14312457]]
# Terjadi error: index 1 is out of bounds for axis 0 with size 1
# cross [[-0.9368512   0.77168927 -2.02551241  0.19067434]]
# Terjadi error: index 1 is out of bounds for axis 0 with size 1
# cross [[-1.42968065  0.943663   -1.87253016  0.35854781]]
# Terjadi error: index 1 is out of bounds for axis 0 with size 1
# cross [[-1.41792461  0.89358931 -2.07220688  0.59654219]]
# Terjadi error: index 1 is out of bounds for axis 0 with size 1
# cross [[-1.01164078  0.74641915 -0.8814857  -0.85329267]]
# Terjadi error: index 1 is out of bounds for axis 0 with size 1
# cross [[-0.70465288  0.72055928 -0.59938141 -1.41652499]]
# Terjadi error: index 1 is out of bounds for axis 0 with size 1
# cross [[-0.18442916  0.77627884 -0.95710103 -1.63474864]]
# Terjadi error: index 1 is out of bounds for axis 0 with size 1
# cross [[ 0.10957192  0.62208502 -0.60598736 -2.12566959]]
# Terjadi error: index 1 is out of bounds for axis 0 with size 1
# cross [[ 0.56807456  0.6171943  -0.71621092 -2.46905794]]
# Terjadi error: index 1 is out of bounds for axis 0 with size 1
# cross [[ 0.17225743  1.17939536 -0.5739064  -2.77774638]]
# Terjadi error: index 1 is out of bounds for axis 0 with size 1
# cross [[ 0.51896377  1.12427687 -1.00114005 -2.64210059]]
# Terjadi error: index 1 is out of bounds for axis 0 with size 1
# cross [[ 0.5536846   0.99857017 -1.07922945 -2.47302531]]
# Terjadi error: index 1 is out of bounds for axis 0 with size 1
# block [[ 0.74523574  0.69256134 -0.97856212 -2.45923497]]
# Terjadi error: type numpy.ndarray doesn't define __round__ method
# block [[ 3.5933006  -0.59038839 -0.8835636  -4.1193486 ]]
# Terjadi error: type numpy.ndarray doesn't define __round__ method
# block [[ 3.76432549 -0.99852803 -1.2079031  -3.55789437]]
# Terjadi error: type numpy.ndarray doesn't define __round__ method
# block [[ 5.39057107 -1.97689976 -0.99249769 -4.42117362]]
# Terjadi error: type numpy.ndarray doesn't define __round__ method
# block [[ 7.88961359 -3.35106336 -0.76088798 -5.77766225]]
# Terjadi error: type numpy.ndarray doesn't define __round__ method
# block [[ 9.71485629 -4.53900732 -0.08536481 -7.09048417]]
# Terjadi error: type numpy.ndarray doesn't define __round__ method
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# block [[ 7.77205294 -2.77756425 -0.1005503  -6.8939384 ]]
# Terjadi error: type numpy.ndarray doesn't define __round__ method
# block [[ 6.94528068 -2.53108025 -0.11200671 -6.30219372]]
# Terjadi error: type numpy.ndarray doesn't define __round__ method
# block [[ 6.08645489 -1.89455061  0.03357455 -6.22547883]]
# Terjadi error: type numpy.ndarray doesn't define __round__ method
# block [[ 5.49646602 -1.72283341  0.09705432 -5.87068693]]
# Terjadi error: type numpy.ndarray doesn't define __round__ method
# block [[ 5.01696408 -1.30026482 -0.04749398 -5.66920528]]
# Terjadi error: type numpy.ndarray doesn't define __round__ method
# block [[ 4.3721294  -1.22600244 -0.77982401 -4.36630295]]
# Terjadi error: type numpy.ndarray doesn't define __round__ method
# block [[ 3.84726155 -1.16494071 -1.227886   -3.45443484]]
# Terjadi error: type numpy.ndarray doesn't define __round__ method
# block [[ 3.52386514 -1.17955734 -1.27177398 -3.07253383]]
# Terjadi error: type numpy.ndarray doesn't define __round__ method
# block [[ 2.97995276 -0.74406451 -1.55319274 -2.68269551]]
# Terjadi error: type numpy.ndarray doesn't define __round__ method
# block [[ 2.64745009 -0.60752835 -1.68303481 -2.35688693]]
# Terjadi error: type numpy.ndarray doesn't define __round__ method
# block [[ 2.28456772 -0.52238399 -1.56830651 -2.19387723]]
# Terjadi error: type numpy.ndarray doesn't define __round__ method
# block [[ 1.75455457  0.05164983 -1.57832757 -2.22787682]]
# Terjadi error: type numpy.ndarray doesn't define __round__ method
# block [[ 1.50503999  0.29493571 -1.55626628 -2.24370942]]
# Terjadi error: type numpy.ndarray doesn't define __round__ method
# block [[ 1.13707178  0.26642679 -1.26882337 -2.1346752 ]]
# Terjadi error: type numpy.ndarray doesn't define __round__ method
# block [[ 0.99882932  0.36871927 -1.463307   -1.90424159]]
# Terjadi error: type numpy.ndarray doesn't define __round__ method
# block [[ 0.70379098  0.54570086 -1.50927312 -1.74021872]]
# Terjadi error: type numpy.ndarray doesn't define __round__ method
# cross [[ 0.47568125  0.53067193 -1.51263644 -1.49371673]]
# Terjadi error: index 1 is out of bounds for axis 0 with size 1
# cross [[ 0.33535284  0.59172509 -1.57127485 -1.35580308]]
# Terjadi error: index 1 is out of bounds for axis 0 with size 1
# cross [[ 0.21663627  0.70304117 -1.65185323 -1.2678242 ]]
# Terjadi error: index 1 is out of bounds for axis 0 with size 1
# cross [[ 0.10782826  0.63126079 -1.632778   -1.10631104]]
# Terjadi error: index 1 is out of bounds for axis 0 with size 1
# cross [[-0.11538998  0.66337492 -1.64319865 -0.90478629]]
# Terjadi error: index 1 is out of bounds for axis 0 with size 1
# cross [[-0.25338967  0.62175704 -1.59198826 -0.77637912]]
# Terjadi error: index 1 is out of bounds for axis 0 with size 1
# cross [[-0.421024    0.74293671 -1.69065786 -0.63125485]]
# Terjadi error: index 1 is out of bounds for axis 0 with size 1
# cross [[-0.5127299   0.84395073 -1.79709536 -0.53412547]]
# Terjadi error: index 1 is out of bounds for axis 0 with size 1
# cross [[-0.38976444  1.09983515 -1.96338039 -0.74669032]]
# Terjadi error: index 1 is out of bounds for axis 0 with size 1
# cross [[-0.50061027  0.96433775 -1.26363594 -1.20009154]]
# Terjadi error: index 1 is out of bounds for axis 0 with size 1
# cross [[-0.57506616  0.86958446 -1.0525187  -1.2419996 ]]
# Terjadi error: index 1 is out of bounds for axis 0 with size 1
# cross [[-0.50933653  0.72814947 -1.03457631 -1.18423663]]
# Terjadi error: index 1 is out of bounds for axis 0 with size 1
# cross [[-0.58242731  0.65257174 -1.00516305 -1.06498139]]
# Terjadi error: index 1 is out of bounds for axis 0 with size 1
# cross [[-0.5904361   0.7134216  -1.10103884 -1.02194666]]
# Terjadi error: index 1 is out of bounds for axis 0 with size 1
# cross [[-0.52513806  0.63270026 -1.07914145 -1.02842075]]
# Terjadi error: index 1 is out of bounds for axis 0 with size 1
# cross [[-0.66935557  0.6892125  -1.03137135 -0.98848559]]
# Terjadi error: index 1 is out of bounds for axis 0 with size 1
# cross [[-0.67268628  0.68016776 -1.06927494 -0.93820654]]
# Terjadi error: index 1 is out of bounds for axis 0 with size 1
# cross [[-0.55569028  0.61733386 -1.01422858 -1.047415  ]]
# Terjadi error: index 1 is out of bounds for axis 0 with size 1
# cross [[-0.6714861   0.73603894 -1.03338382 -1.03116902]]
# Terjadi error: index 1 is out of bounds for axis 0 with size 1
# cross [[-0.67466678  0.79505284 -1.02330168 -1.09708438]]
# Terjadi error: index 1 is out of bounds for axis 0 with size 1
# cross [[-0.77881316  0.94257046 -1.00817817 -1.15557914]]
# Terjadi error: index 1 is out of bounds for axis 0 with size 1
# cross [[-0.93960342  1.01450708 -0.78022029 -1.29468337]]
# Terjadi error: index 1 is out of bounds for axis 0 with size 1
# cross [[-0.86101305  0.87827676 -0.40600099 -1.61126271]]
# Terjadi error: index 1 is out of bounds for axis 0 with size 1
# cross [[-0.61418091  0.69247448 -0.38518431 -1.69310925]]
# Terjadi error: index 1 is out of bounds for axis 0 with size 1
# cross [[-0.29451384  0.27059501 -0.24631862 -1.72976255]]
# Terjadi error: index 1 is out of bounds for axis 0 with size 1
# block [[ 0.96962742 -0.21681677 -1.10648118 -1.64632947]]
# Terjadi error: type numpy.ndarray doesn't define __round__ method
# block [[ 2.85034713 -1.19042185 -1.08028468 -2.5796406 ]]
# Terjadi error: type numpy.ndarray doesn't define __round__ method
# block [[ 3.54662438 -1.47892966 -0.79097493 -3.27671979]]
# Terjadi error: type numpy.ndarray doesn't define __round__ method
# block [[ 3.52471596 -1.73342092 -0.89319028 -2.89810476]]
# Terjadi error: type numpy.ndarray doesn't define __round__ method
# block [[ 3.03042308 -1.7015458  -0.94427691 -2.38460038]]
# Terjadi error: type numpy.ndarray doesn't define __round__ method
# block [[ 2.76395823 -1.4153126  -0.96108357 -2.38756206]]
# Terjadi error: type numpy.ndarray doesn't define __round__ method
# block [[ 2.27767865 -1.27712929 -0.68939748 -2.31115188]]
# Terjadi error: type numpy.ndarray doesn't define __round__ method
# block [[ 2.16401035 -1.02407672 -0.9458719  -2.19406173]]
# Terjadi error: type numpy.ndarray doesn't define __round__ method
# block [[ 1.78772591 -0.93760062 -0.63920042 -2.21092487]]
# Terjadi error: type numpy.ndarray doesn't define __round__ method
# block [[ 1.44878658 -0.76763882 -0.64645815 -2.03468961]]
# Terjadi error: type numpy.ndarray doesn't define __round__ method
# block [[ 1.20898723 -0.68702429 -0.61283041 -1.90913253]]
# Terjadi error: type numpy.ndarray doesn't define __round__ method
# block [[ 1.05636291 -0.61184564 -0.62810299 -1.81641428]]
# Terjadi error: type numpy.ndarray doesn't define __round__ method
# block [[ 0.91850047 -0.59569138 -0.68787233 -1.63493676]]
# Terjadi error: type numpy.ndarray doesn't define __round__ method
# block [[ 0.81926663 -0.49941956 -0.80780171 -1.51204537]]
# Terjadi error: type numpy.ndarray doesn't define __round__ method
# block [[ 0.53278621 -0.44855507 -0.88676276 -1.19746838]]
# Terjadi error: type numpy.ndarray doesn't define __round__ method
# block [[ 0.48272797 -0.5255491  -0.90795881 -1.04922006]]
# Terjadi error: type numpy.ndarray doesn't define __round__ method
# block [[ 0.3121385  -0.43463901 -1.10415671 -0.77334278]]
# Terjadi error: type numpy.ndarray doesn't define __round__ method
# block [[ 0.10426583 -0.29599327 -1.01920456 -0.78906801]]
# Terjadi error: type numpy.ndarray doesn't define __round__ method
# block [[-0.02509394 -0.18908681 -0.81680561 -0.96901364]]
# Terjadi error: type numpy.ndarray doesn't define __round__ method
# cross [[-0.26081058  0.04739287 -0.60468941 -1.18189287]]
# Terjadi error: index 1 is out of bounds for axis 0 with size 1
# cross [[-0.12394007  0.03823452 -0.80855546 -1.105739  ]]
# Terjadi error: index 1 is out of bounds for axis 0 with size 1
# cross [[-0.35639008  0.35743496 -0.70321695 -1.29782793]]
# Terjadi error: index 1 is out of bounds for axis 0 with size 1
# cross [[-0.41177732  0.43711714 -0.72401619 -1.30132363]]
# Terjadi error: index 1 is out of bounds for axis 0 with size 1
# cross [[-0.40500743  0.38538627 -0.79504076 -1.18533808]]
# Terjadi error: index 1 is out of bounds for axis 0 with size 1
# cross [[-0.49005598  0.42233712 -0.77105993 -1.16122122]]
# Terjadi error: index 1 is out of bounds for axis 0 with size 1
# cross [[-0.68751163  0.52961224 -1.23483832 -0.60726229]]
# Terjadi error: index 1 is out of bounds for axis 0 with size 1
# cross [[-0.68390745  0.35517825 -1.46208552 -0.20918528]]
# Terjadi error: index 1 is out of bounds for axis 0 with size 1
# cross [[-0.75824124  0.41475308 -1.50645996 -0.15005187]]
# Terjadi error: index 1 is out of bounds for axis 0 with size 1
# cross [[-0.84651691  0.49616965 -1.6365107  -0.01314204]]
# Terjadi error: index 1 is out of bounds for axis 0 with size 1
# cross [[-0.93524094  0.49063292 -1.81599496  0.26060298]]
# Terjadi error: index 1 is out of bounds for axis 0 with size 1
# cross [[-0.72809552  0.76237216 -2.57562383  0.54134718]]
# Terjadi error: index 1 is out of bounds for axis 0 with size 1
# uppercut [[-1.5020845   0.58773903 -1.73073977  0.64508525]]
# Terjadi error: index 3 is out of bounds for axis 0 with size 1
# cross [[-1.74521412  0.91576632 -1.6129      0.4423478 ]]
# Terjadi error: index 1 is out of bounds for axis 0 with size 1
# cross [[-2.00779282  1.13387174 -1.4602094   0.33413048]]
# Terjadi error: index 1 is out of bounds for axis 0 with size 1
# cross [[-1.70518124  1.06386787 -1.46881416  0.11012752]]
# Terjadi error: index 1 is out of bounds for axis 0 with size 1
# cross [[-1.31125658  0.92942287 -1.38257458 -0.23559171]]
# Terjadi error: index 1 is out of bounds for axis 0 with size 1
# cross [[-1.17214092  0.69777198 -1.48168359 -0.04394748]]
# Terjadi error: index 1 is out of bounds for axis 0 with size 1
# cross [[-1.19974512  0.75569047 -1.84096503  0.28501968]]
# Terjadi error: index 1 is out of bounds for axis 0 with size 1
# uppercut [[-1.08593382  0.35463762 -2.02625366  0.75754985]]
# Terjadi error: index 3 is out of bounds for axis 0 with size 1
# uppercut [[-0.8537409   0.19412165 -2.16432665  0.8239459 ]]
# Terjadi error: index 3 is out of bounds for axis 0 with size 1
# uppercut [[-1.04754825  0.43343798 -2.17264658  0.78675684]]
# Terjadi error: index 3 is out of bounds for axis 0 with size 1
# uppercut [[-1.05184046  0.55456692 -2.4492904   0.94656394]]
# Terjadi error: index 3 is out of bounds for axis 0 with size 1
# uppercut [[-1.02927994  0.11958933 -2.46142193  1.37111253]]
# Terjadi error: index 3 is out of bounds for axis 0 with size 1
# uppercut [[-0.9592978   0.21009371 -2.70543026  1.45463434]]
# Terjadi error: index 3 is out of bounds for axis 0 with size 1
# uppercut [[-1.1046752   0.60271582 -2.59214655  1.09410592]]
# Terjadi error: index 3 is out of bounds for axis 0 with size 1
# cross [[-1.13595616  1.20231704 -2.09532362  0.02896274]]
# Terjadi error: index 1 is out of bounds for axis 0 with size 1
# cross [[-1.56531068  2.37833382 -1.35372324 -1.45929991]]
# Terjadi error: index 1 is out of bounds for axis 0 with size 1
# cross [[-1.21296413  2.30224573 -1.00534096 -2.08394064]]
# Terjadi error: index 1 is out of bounds for axis 0 with size 1
# cross [[-1.27610366  1.54473676 -1.7675422  -0.50109091]]
# Terjadi error: index 1 is out of bounds for axis 0 with size 1
# cross [[-1.10624265  1.61830915 -1.72348467 -0.78858183]]
# Terjadi error: index 1 is out of bounds for axis 0 with size 1
# cross [[-1.06362453  1.13449083 -1.88141843 -0.18944787]]
# Terjadi error: index 1 is out of bounds for axis 0 with size 1
# cross [[-1.20994     2.35684974 -0.8868705  -2.26003923]]
# Terjadi error: index 1 is out of bounds for axis 0 with size 1
# cross [[-1.07074417  1.86844174 -0.11025677 -2.6874408 ]]
# Terjadi error: index 1 is out of bounds for axis 0 with size 1
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# cross [[ 0.03465931  2.60560993 -0.55110261 -4.08916664]]
# Terjadi error: index 1 is out of bounds for axis 0 with size 1
# cross [[ 0.4855234   2.71087041 -0.94095995 -4.25543386]]
# Terjadi error: index 1 is out of bounds for axis 0 with size 1
# cross [[ 0.38220358  2.57144767 -0.77718382 -4.17646744]]
# Terjadi error: index 1 is out of bounds for axis 0 with size 1
# cross [[ 0.18438909  2.37430013 -0.61604535 -3.94264386]]
# Terjadi error: index 1 is out of bounds for axis 0 with size 1
# cross [[ 0.023666    2.19874106 -0.51914729 -3.70325976]]
# Terjadi error: index 1 is out of bounds for axis 0 with size 1
# cross [[ 0.00588558  2.15371675 -0.52075155 -3.63885077]]
# Terjadi error: index 1 is out of bounds for axis 0 with size 1
# cross [[-0.27985132  1.94172405 -0.49317059 -3.16870213]]
# Terjadi error: index 1 is out of bounds for axis 0 with size 1
# cross [[-0.31999269  1.84547518 -0.42425017 -3.10123231]]
# Terjadi error: index 1 is out of bounds for axis 0 with size 1
# cross [[-0.21827989  1.48399978 -0.5956398  -2.67008009]]
# Terjadi error: index 1 is out of bounds for axis 0 with size 1
# cross [[-0.19787425  1.17887572 -0.57177424 -2.40922724]]
# Terjadi error: index 1 is out of bounds for axis 0 with size 1
# cross [[-0.11053057  1.10107711 -0.73545944 -2.2550871 ]]
# Terjadi error: index 1 is out of bounds for axis 0 with size 1
# cross [[-0.12186452  0.88809586 -0.70977452 -2.05645682]]
# Terjadi error: index 1 is out of bounds for axis 0 with size 1
# cross [[-0.27502059  0.94941842 -0.71182699 -1.96257085]]
# Terjadi error: index 1 is out of bounds for axis 0 with size 1
# cross [[-0.34022289  0.9518179  -0.95585029 -1.65574472]]
# Terjadi error: index 1 is out of bounds for axis 0 with size 1
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# block [[ 1.77013095 -0.91696331 -1.14350807 -1.70965957]]
# Terjadi error: type numpy.ndarray doesn't define __round__ method
# block [[ 2.38833461 -1.96404029 -1.21055431 -1.21374001]]
# Terjadi error: type numpy.ndarray doesn't define __round__ method
# block [[ 3.10389677 -2.29048673 -0.38963122 -2.42377883]]
# Terjadi error: type numpy.ndarray doesn't define __round__ method
# block [[ 3.16677676 -1.71650826 -0.28756346 -3.16270504]]
# Terjadi error: type numpy.ndarray doesn't define __round__ method
# block [[ 2.69249589 -1.43445657  0.06382193 -3.32186125]]
# Terjadi error: type numpy.ndarray doesn't define __round__ method
# block [[ 2.48061442 -1.31835289  0.13047467 -3.2927362 ]]
# Terjadi error: type numpy.ndarray doesn't define __round__ method
# block [[ 1.2521828  -2.28655271  0.88446828 -1.85009838]]
# Terjadi error: type numpy.ndarray doesn't define __round__ method
# block [[ 1.064867   -2.73224594  0.46533906 -0.79796012]]
# Terjadi error: type numpy.ndarray doesn't define __round__ method
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# block [[ 0.29706069 -1.83786551 -0.20446977 -0.25472542]]
# Terjadi error: type numpy.ndarray doesn't define __round__ method
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# uppercut [[-0.01018617 -0.5915778  -1.43074263  0.03250659]]
# Terjadi error: index 3 is out of bounds for axis 0 with size 1
# uppercut [[-0.17501842 -1.08058283 -1.21613252  0.47173376]]
# Terjadi error: index 3 is out of bounds for axis 0 with size 1
# uppercut [[-0.21744115 -0.96978777 -1.6737165   0.86094542]]
# Terjadi error: index 3 is out of bounds for axis 0 with size 1
# uppercut [[-0.68764932 -0.45328197 -1.77797976  0.91891105]]
# Terjadi error: index 3 is out of bounds for axis 0 with size 1
# uppercut [[-0.83835491 -0.53605581 -1.67206176  1.04647248]]
# Terjadi error: index 3 is out of bounds for axis 0 with size 1
# uppercut [[-0.87409631 -0.54468824 -1.99162584  1.4104104 ]]
# Terjadi error: index 3 is out of bounds for axis 0 with size 1
# uppercut [[-1.02361151 -0.54645031 -2.15357211  1.72363393]]
# Terjadi error: index 3 is out of bounds for axis 0 with size 1
# uppercut [[-1.1424927  -0.62111211 -2.12787885  1.89148367]]
# Terjadi error: index 3 is out of bounds for axis 0 with size 1
# uppercut [[-1.1519887  -0.32114097 -1.89016504  1.3632947 ]]
# Terjadi error: index 3 is out of bounds for axis 0 with size 1
# uppercut [[-1.7165213   0.11604735 -1.86354576  1.46401971]]
# Terjadi error: index 3 is out of bounds for axis 0 with size 1
# uppercut [[-1.703014    0.40202434 -1.56424499  0.86523465]]
# Terjadi error: index 3 is out of bounds for axis 0 with size 1
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# uppercut [[-0.10662225 -0.21888608 -1.8098067   0.13531503]]
# Terjadi error: index 3 is out of bounds for axis 0 with size 1
# block [[ 1.00818348 -0.61095185 -1.72518171 -0.67204992]]
# Terjadi error: type numpy.ndarray doesn't define __round__ method
# block [[ 1.9171846  -1.12523591 -1.53317156 -1.25877712]]
# Terjadi error: type numpy.ndarray doesn't define __round__ method
# block [[ 1.7287492  -1.17410867 -1.01338254 -1.541258  ]]
# Terjadi error: type numpy.ndarray doesn't define __round__ method
# block [[ 1.77269193 -0.96007705 -0.84605258 -1.9665623 ]]
# Terjadi error: type numpy.ndarray doesn't define __round__ method
# block [[ 1.85640912 -1.01071786 -0.86323674 -1.98245452]]
# Terjadi error: type numpy.ndarray doesn't define __round__ method
# block [[ 1.65363418 -0.76259124 -1.45210054 -1.43894241]]
# Terjadi error: type numpy.ndarray doesn't define __round__ method
# block [[ 1.33667209 -0.45755566 -1.51627347 -1.36284296]]
# Terjadi error: type numpy.ndarray doesn't define __round__ method
# block [[ 1.16369149 -0.30291574 -1.55780524 -1.30297051]]
# Terjadi error: type numpy.ndarray doesn't define __round__ method
# block [[ 1.01434054 -0.15289585 -1.65259628 -1.20884841]]
# Terjadi error: type numpy.ndarray doesn't define __round__ method
# block [[ 0.78764039 -0.02069861 -1.51467694 -1.25226484]]
# Terjadi error: type numpy.ndarray doesn't define __round__ method
# block [[ 0.65219286  0.19453175 -1.62862761 -1.218097  ]]
# Terjadi error: type numpy.ndarray doesn't define __round__ method
# block [[ 0.612594    0.13174827 -1.5415698  -1.20277247]]
# Terjadi error: type numpy.ndarray doesn't define __round__ method
# block [[ 1.01670849 -0.22042691 -1.4484858  -1.34779578]]
# Terjadi error: type numpy.ndarray doesn't define __round__ method
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# block [[ 4.87664729 -2.19740721 -0.87233898 -3.8069011 ]]
# Terjadi error: type numpy.ndarray doesn't define __round__ method
# block [[ 3.88579058 -1.5727383  -1.64893917 -2.66411312]]
# Terjadi error: type numpy.ndarray doesn't define __round__ method
# block [[ 2.73741324 -1.15114662 -1.58657126 -1.99969536]]
# Terjadi error: type numpy.ndarray doesn't define __round__ method
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# block [[ 2.33750882  1.23082896 -3.42145514 -2.14688264]]
# Terjadi error: type numpy.ndarray doesn't define __round__ method
# block [[ 3.10038258  0.81380145 -3.04454702 -2.86963701]]
# Terjadi error: type numpy.ndarray doesn't define __round__ method
# block [[ 3.27760268  0.53375081 -2.95290314 -2.85845035]]
# Terjadi error: type numpy.ndarray doesn't define __round__ method
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# block [[ 4.76725982  1.59843554 -1.86586891 -6.49982645]]
# Terjadi error: type numpy.ndarray doesn't define __round__ method
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# block [[ 5.18559699  1.11266628 -0.60944781 -7.68881545]]
# Terjadi error: type numpy.ndarray doesn't define __round__ method
# block [[ 4.67511712  0.8960289  -0.70460752 -6.8665385 ]]
# Terjadi error: type numpy.ndarray doesn't define __round__ method
# block [[ 3.84203268  1.38813119 -0.9299876  -6.30017627]]
# Terjadi error: type numpy.ndarray doesn't define __round__ method
# block [[ 3.92553604  0.79925675 -0.73650392 -5.98828887]]
# Terjadi error: type numpy.ndarray doesn't define __round__ method
# block [[ 3.92469511  0.52226279 -0.82566761 -5.62129029]]
# Terjadi error: type numpy.ndarray doesn't define __round__ method
# block [[ 3.59429333  0.36087136 -0.73002983 -5.22513486]]
# Terjadi error: type numpy.ndarray doesn't define __round__ method
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# block [[ 1.89800014  0.0920499  -1.65033098 -2.33971905]]
# Terjadi error: type numpy.ndarray doesn't define __round__ method
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# block [[ 1.01828489 -0.38270422 -1.39816628 -1.23741439]]
# Terjadi error: type numpy.ndarray doesn't define __round__ method
# block [[ 0.6826706  -0.30461296 -1.19655764 -1.1815    ]]
# Terjadi error: type numpy.ndarray doesn't define __round__ method
# block [[ 0.33288025 -0.16820401 -1.06245636 -1.10221988]]
# Terjadi error: type numpy.ndarray doesn't define __round__ method
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# block [[-0.01922691 -0.10900595 -1.05684417 -0.81492297]]
# Terjadi error: type numpy.ndarray doesn't define __round__ method
# block [[-0.03877542 -0.116112   -0.95800612 -0.88710646]]
# Terjadi error: type numpy.ndarray doesn't define __round__ method
# block [[-0.09697246 -0.17790042 -0.91245737 -0.81266976]]
# Terjadi error: type numpy.ndarray doesn't define __round__ method
# block [[ 0.0117065  -0.26932219 -1.07687234 -0.66551197]]
# Terjadi error: type numpy.ndarray doesn't define __round__ method
# block [[ 0.02097865 -0.30995209 -1.13227504 -0.57875153]]
# Terjadi error: type numpy.ndarray doesn't define __round__ method
# block [[-0.07431889 -0.26278408 -1.10328548 -0.55961155]]
# Terjadi error: type numpy.ndarray doesn't define __round__ method
# block [[-0.09362143 -0.34537822 -1.03284832 -0.52815203]]
# Terjadi error: type numpy.ndarray doesn't define __round__ method
# block [[-0.185866   -0.28751257 -1.02428075 -0.50234068]]
# Terjadi error: type numpy.ndarray doesn't define __round__ method
# block [[-0.24841817 -0.35255919 -1.05999714 -0.3390255 ]]
# Terjadi error: type numpy.ndarray doesn't define __round__ method
# block [[-0.3094959  -0.31530428 -0.92686283 -0.44833699]]
# Terjadi error: type numpy.ndarray doesn't define __round__ method
# block [[-0.30048279 -0.42052817 -0.93373985 -0.34524919]]
# Terjadi error: type numpy.ndarray doesn't define __round__ method
# cross [[-0.37633917 -0.25667724 -1.07286447 -0.29411912]]
# Terjadi error: index 1 is out of bounds for axis 0 with size 1
# uppercut [[-0.32694583 -0.45275411 -0.95206082 -0.26823924]]
# Terjadi error: index 3 is out of bounds for axis 0 with size 1
# uppercut [[-0.25170107 -0.46434809 -1.0743582  -0.20959264]]
# Terjadi error: index 3 is out of bounds for axis 0 with size 1
# uppercut [[-0.23119698 -0.34635345 -1.21064513 -0.21180443]]
# Terjadi error: index 3 is out of bounds for axis 0 with size 1
# uppercut [[-0.36548782 -0.3461018  -1.11314927 -0.17526111]]
# Terjadi error: index 3 is out of bounds for axis 0 with size 1
# uppercut [[-0.40082674 -0.37516522 -1.08963868 -0.13436936]]
# Terjadi error: index 3 is out of bounds for axis 0 with size 1
# uppercut [[-0.36549433 -0.38284044 -1.11006032 -0.14160491]]
# Terjadi error: index 3 is out of bounds for axis 0 with size 1
# cross [[-0.45068375 -0.21222546 -1.0516501  -0.28544068]]
# Terjadi error: index 1 is out of bounds for axis 0 with size 1
# uppercut [[-0.35296283 -0.30683779 -1.11206841 -0.22813097]]
# Terjadi error: index 3 is out of bounds for axis 0 with size 1
# uppercut [[-0.44302979 -0.26648992 -1.0739964  -0.21648389]]
# Terjadi error: index 3 is out of bounds for axis 0 with size 1
# cross [[-0.39341972 -0.19887328 -1.12156691 -0.28614009]]
# Terjadi error: index 1 is out of bounds for axis 0 with size 1
# uppercut [[-0.32367834 -0.36940038 -1.07013522 -0.23678606]]
# Terjadi error: index 3 is out of bounds for axis 0 with size 1
# uppercut [[-0.40714142 -0.37081002 -1.00271977 -0.21932879]]
# Terjadi error: index 3 is out of bounds for axis 0 with size 1
# uppercut [[-0.42428323 -0.43306599 -0.96183147 -0.18081931]]
# Terjadi error: index 3 is out of bounds for axis 0 with size 1
# uppercut [[-0.34850401 -0.53301944 -1.00266334 -0.11581321]]
# Terjadi error: index 3 is out of bounds for axis 0 with size 1
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# uppercut [[-0.34787849 -0.31047426 -1.18121596 -0.16043128]]
# Terjadi error: index 3 is out of bounds for axis 0 with size 1
# uppercut [[-0.48447337 -0.75734137 -0.91471231  0.15652705]]
# Terjadi error: index 3 is out of bounds for axis 0 with size 1
# uppercut [[-0.78829374 -0.84449232 -0.85143532  0.48422138]]
# Terjadi error: index 3 is out of bounds for axis 0 with size 1
# uppercut [[-0.88367537 -0.8490926  -1.07953553  0.81230351]]
# Terjadi error: index 3 is out of bounds for axis 0 with size 1
# uppercut [[-1.23608078 -0.31003869 -1.10738503  0.6535045 ]]
# Terjadi error: index 3 is out of bounds for axis 0 with size 1
# uppercut [[-1.27796527 -0.07268158 -1.21314139  0.56378823]]
# Terjadi error: index 3 is out of bounds for axis 0 with size 1
# uppercut [[-1.2242038   0.02114993 -1.21405205  0.41710592]]
# Terjadi error: index 3 is out of bounds for axis 0 with size 1
# uppercut [[-1.24405461 -0.08554056 -1.22125246  0.55084763]]
# Terjadi error: index 3 is out of bounds for axis 0 with size 1
# uppercut [[-1.42952302  0.18340641 -1.22822549  0.4743421 ]]
# Terjadi error: index 3 is out of bounds for axis 0 with size 1
# uppercut [[-1.18931159  0.01676492 -1.10144015  0.27398681]]
# Terjadi error: index 3 is out of bounds for axis 0 with size 1
# cross [[-1.61441278  0.40504576 -1.07257697  0.28194399]]
# Terjadi error: index 1 is out of bounds for axis 0 with size 1
# uppercut [[-1.51889604 -0.18340452 -1.40214757  1.10444813]]
# Terjadi error: index 3 is out of bounds for axis 0 with size 1
# uppercut [[-1.22420957 -0.43401384 -1.40496903  1.06319244]]
# Terjadi error: index 3 is out of bounds for axis 0 with size 1
# uppercut [[-1.34225979 -0.45552468 -1.30675701  1.10454148]]
# Terjadi error: index 3 is out of bounds for axis 0 with size 1
# uppercut [[-1.18407882 -0.74891927 -1.25952843  1.19252652]]
# Terjadi error: index 3 is out of bounds for axis 0 with size 1
# uppercut [[-1.22174958 -0.70532509 -1.23126755  1.15834222]]
# Terjadi error: index 3 is out of bounds for axis 0 with size 1
# uppercut [[-1.32893564 -0.72054769 -1.28968533  1.33916866]]
# Terjadi error: index 3 is out of bounds for axis 0 with size 1
# cross [[-1.56110906  0.53259132 -1.00009194  0.02860968]]
# Terjadi error: index 1 is out of bounds for axis 0 with size 1
# cross [[-1.6855726   0.7083383  -0.7015808  -0.32118489]]
# Terjadi error: index 1 is out of bounds for axis 0 with size 1
# cross [[-1.56712977  0.50139606 -0.64602928 -0.28823702]]
# Terjadi error: index 1 is out of bounds for axis 0 with size 1
# cross [[-1.49679721  0.45077638 -0.575181   -0.37879817]]
# Terjadi error: index 1 is out of bounds for axis 0 with size 1
# cross [[-1.6779475   0.555291    0.04377208 -0.92111559]]
# Terjadi error: index 1 is out of bounds for axis 0 with size 1
# cross [[-1.49629749  0.59458982  0.14465418 -1.24294651]]
# Terjadi error: index 1 is out of bounds for axis 0 with size 1
# cross [[-1.29547673  0.57338555  0.17056135 -1.44847017]]
# Terjadi error: index 1 is out of bounds for axis 0 with size 1
# cross [[-1.08468989  0.37136598  0.14461766 -1.43129375]]
# Terjadi error: index 1 is out of bounds for axis 0 with size 1
# jab [[-1.19707529  0.26250892  0.30216203 -1.36759566]]
# Terjadi error: index 2 is out of bounds for axis 0 with size 1
# cross [[-1.22156316  0.38632505  0.25806117 -1.42282306]]
# Terjadi error: index 1 is out of bounds for axis 0 with size 1
# jab [[-1.25653892  0.23248762  0.29737541 -1.27332412]]
# Terjadi error: index 2 is out of bounds for axis 0 with size 1
# jab [[-1.36960573  0.28477242  0.38188395 -1.29705064]]
# Terjadi error: index 2 is out of bounds for axis 0 with size 1
# jab [[-1.3474166   0.16855175  0.53668286 -1.35781801]]
# Terjadi error: index 2 is out of bounds for axis 0 with size 1
# jab [[-1.23969176  0.23356441  0.37584237 -1.36971502]]
# Terjadi error: index 2 is out of bounds for axis 0 with size 1
# jab [[-1.35656771  0.25073511  0.33830027 -1.23246767]]
# Terjadi error: index 2 is out of bounds for axis 0 with size 1
# jab [[-1.24472043  0.07074525  0.37380041 -1.19982523]]
# Terjadi error: index 2 is out of bounds for axis 0 with size 1
# jab [[-1.385194    0.17430608  0.55278964 -1.34190172]]
# Terjadi error: index 2 is out of bounds for axis 0 with size 1
# jab [[-1.50258125  0.06634836  0.61241358 -1.17618068]]
# Terjadi error: index 2 is out of bounds for axis 0 with size 1
# jab [[-1.48506129  0.23325288  0.56385671 -1.31204831]]
# Terjadi error: index 2 is out of bounds for axis 0 with size 1
# jab [[-1.33909986  0.09145474  0.49432241 -1.24667729]]
# Terjadi error: index 2 is out of bounds for axis 0 with size 1
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# jab [[-1.32940489  0.61101989  0.81271779 -2.09433279]]
# Terjadi error: index 2 is out of bounds for axis 0 with size 1
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# cross [[-1.20448225  0.52633735  0.46496065 -1.78681574]]
# Terjadi error: index 1 is out of bounds for axis 0 with size 1
# jab [[-0.62460907 -0.06853706  0.6534969  -1.96035077]]
# Terjadi error: index 2 is out of bounds for axis 0 with size 1
# jab [[-0.71509117 -0.17198984  0.56282028 -1.67573927]]
# Terjadi error: index 2 is out of bounds for axis 0 with size 1
# jab [[-0.77480237  0.02378896  0.52210833 -1.77109492]]
# Terjadi error: index 2 is out of bounds for axis 0 with size 1
# jab [[-0.59652028 -0.5402392   0.77411069 -1.63735121]]
# Terjadi error: index 2 is out of bounds for axis 0 with size 1
# jab [[-1.01265074 -0.66884148  0.12329605 -0.44180384]]
# Terjadi error: index 2 is out of bounds for axis 0 with size 1
# jab [[-1.00707339 -0.69729553  0.12683772 -0.4224688 ]]
# Terjadi error: index 2 is out of bounds for axis 0 with size 1
# jab [[-0.99556769 -0.73933279  0.23417226 -0.49927177]]
# Terjadi error: index 2 is out of bounds for axis 0 with size 1
# ...
# uppercut [[-1.31491027  0.28176929 -1.79853511  0.83167609]]
# Terjadi error: index 3 is out of bounds for axis 0 with size 1
# uppercut [[-1.37697306  0.37221072 -1.79516288  0.79992521]]
# Terjadi error: index 3 is out of bounds for axis 0 with size 1
# uppercut [[-1.29454112  0.35070989 -2.06909797  1.01292921]]
# Terjadi error: index 3 is out of bounds for axis 0 with size 1
# uppercut [[-1.26241629  0.1765172  -1.98745029  1.07334937]]
# Terjadi error: index 3 is out of bounds for axis 0 with size 1
# uppercut [[-1.30550291  0.26749738 -2.02095192  1.05895745]]
# Terjadi error: index 3 is out of bounds for axis 0 with size 1
# uppercut [[-1.3938161   0.2993158  -1.96217391  1.05667421]]
# Terjadi error: index 3 is out of bounds for axis 0 with size 1
# uppercut [[-1.43163748  0.2904301  -1.87251351  1.01372089]]
# Terjadi error: index 3 is out of bounds for axis 0 with size 1
# uppercut [[-1.46467339  0.32986357 -1.99291912  1.12772893]]
# Terjadi error: index 3 is out of bounds for axis 0 with size 1
# uppercut [[-1.48292636  0.36760665 -1.96226539  1.07758511]]
# Terjadi error: index 3 is out of bounds for axis 0 with size 1
# uppercut [[-1.68245658  0.56834149 -1.85621772  0.97033281]]
# Terjadi error: index 3 is out of bounds for axis 0 with size 1
# uppercut [[-1.71807164  0.76144277 -1.93959928  0.89622815]]
# Terjadi error: index 3 is out of bounds for axis 0 with size 1
# uppercut [[-1.77776853  0.78196064 -1.90758101  0.9033889 ]]
# Terjadi error: index 3 is out of bounds for axis 0 with size 1
# uppercut [[-1.84978033  0.76518766 -1.79320518  0.87779786]]
# Terjadi error: index 3 is out of bounds for axis 0 with size 1
# uppercut [[-1.79828299  0.65681169 -1.7902074   0.9316787 ]]
# Terjadi error: index 3 is out of bounds for axis 0 with size 1
# cross [[-1.78530414  0.79622108 -1.4480298   0.43711286]]
# Terjadi error: index 1 is out of bounds for axis 0 with size 1
# cross [[-1.69847711  0.74155437 -1.3444745   0.30139724]]
# Terjadi error: index 1 is out of bounds for axis 0 with size 1
# cross [[-1.74786715  0.80089134 -1.35196577  0.29894158]]
# Terjadi error: index 1 is out of bounds for axis 0 with size 1
# cross [[-1.51747737  0.56871977 -1.26165753  0.21041513]]
# Terjadi error: index 1 is out of bounds for axis 0 with size 1
# cross [[-1.62136233  0.64084638 -1.27112191  0.25163785]]
# Terjadi error: index 1 is out of bounds for axis 0 with size 1
# cross [[-1.55941977  0.70476007 -1.31865812  0.17331781]]
# Terjadi error: index 1 is out of bounds for axis 0 with size 1
# cross [[-1.4599875   0.63165047 -1.36393155  0.19226857]]
# Terjadi error: index 1 is out of bounds for axis 0 with size 1
# cross [[-1.46083325  0.60326225 -1.33732239  0.19489339]]
# Terjadi error: index 1 is out of bounds for axis 0 with size 1
# cross [[-1.35974851  0.50132843 -1.34466669  0.20308676]]
# Terjadi error: index 1 is out of bounds for axis 0 with size 1
# cross [[-1.40106205  0.48071654 -1.28098387  0.20132938]]
# Terjadi error: index 1 is out of bounds for axis 0 with size 1
# uppercut [[-1.43166621  0.32992494 -1.71111822  0.81285949]]
# Terjadi error: index 3 is out of bounds for axis 0 with size 1
# uppercut [[-1.54087683  0.37535148 -1.68337787  0.84890321]]
# Terjadi error: index 3 is out of bounds for axis 0 with size 1
# uppercut [[-1.61813061  0.42732978 -1.67565198  0.86645282]]
# Terjadi error: index 3 is out of bounds for axis 0 with size 1
# uppercut [[-1.57822769  0.48522056 -1.68340041  0.77640755]]
# Terjadi error: index 3 is out of bounds for axis 0 with size 1
# uppercut [[-1.59115947  0.47629071 -1.71819612  0.83306488]]
# Terjadi error: index 3 is out of bounds for axis 0 with size 1
# cross [[-1.37571243  0.50778006 -1.42196906  0.28990143]]
# Terjadi error: index 1 is out of bounds for axis 0 with size 1
# cross [[-1.37602469  0.49667274 -1.35568038  0.23503234]]
# Terjadi error: index 1 is out of bounds for axis 0 with size 1
# cross [[-1.33343916  0.52371896 -1.27923405  0.08895426]]
# Terjadi error: index 1 is out of bounds for axis 0 with size 1
# cross [[-1.31554013  0.36932754 -1.12116725  0.06737984]]
# Terjadi error: index 1 is out of bounds for axis 0 with size 1
# cross [[-1.42043141  0.54150122 -1.23101892  0.10994911]]
# Terjadi error: index 1 is out of bounds for axis 0 with size 1
# cross [[-1.38715178  0.49074192 -1.20876436  0.10517421]]
# Terjadi error: index 1 is out of bounds for axis 0 with size 1
# cross [[-1.42282299  0.45564196 -1.05290388  0.02008491]]
# Terjadi error: index 1 is out of bounds for axis 0 with size 1
# cross [[-1.45219135  0.523955   -0.93216603 -0.13959762]]
# Terjadi error: index 1 is out of bounds for axis 0 with size 1
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# uppercut [[-1.14697517  0.38636326 -1.83451202  0.59512393]]
# Terjadi error: index 3 is out of bounds for axis 0 with size 1
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# jab [[-0.4247006  -1.0221871  -0.23158193 -0.32153036]]
# Terjadi error: index 2 is out of bounds for axis 0 with size 1
# uppercut [[-0.79070218 -0.81541225 -0.36586743 -0.02801814]]
# Terjadi error: index 3 is out of bounds for axis 0 with size 1
# uppercut [[-0.85432621 -0.81999477 -0.52483002  0.199151  ]]
# Terjadi error: index 3 is out of bounds for axis 0 with size 1
# uppercut [[-0.6714354  -0.47753712 -0.89305375  0.04202626]]
# Terjadi error: index 3 is out of bounds for axis 0 with size 1
# uppercut [[-0.5292131  -0.54141326 -0.48324912 -0.44612452]]
# Terjadi error: index 3 is out of bounds for axis 0 with size 1
# cross [[-0.72880038 -0.32156278 -0.36677469 -0.58286215]]
# Terjadi error: index 1 is out of bounds for axis 0 with size 1
# cross [[-0.68521054 -0.35064552 -0.51857947 -0.44556447]]
# Terjadi error: index 1 is out of bounds for axis 0 with size 1
# cross [[-0.61451683 -0.3397692  -0.59901377 -0.4467002 ]]
# Terjadi error: index 1 is out of bounds for axis 0 with size 1
# uppercut [[-0.55298594 -0.43985216 -0.62027793 -0.38688396]]
# Terjadi error: index 3 is out of bounds for axis 0 with size 1
# uppercut [[-0.61986619 -0.45017243 -0.60115482 -0.32880656]]
# Terjadi error: index 3 is out of bounds for axis 0 with size 1
# uppercut [[-0.50502675 -0.42596887 -0.71013376 -0.35887062]]
# Terjadi error: index 3 is out of bounds for axis 0 with size 1
# block [[-0.40751708 -0.63043255 -0.52972862 -0.43232175]]
# Terjadi error: type numpy.ndarray doesn't define __round__ method
# block [[-0.46358553 -0.53479714 -0.50141177 -0.50020556]]
# Terjadi error: type numpy.ndarray doesn't define __round__ method
# block [[-0.32363215 -0.64371929 -0.41619056 -0.616458  ]]
# Terjadi error: type numpy.ndarray doesn't define __round__ method
# block [[-0.33573768 -0.61139742 -0.40647423 -0.64639066]]
# Terjadi error: type numpy.ndarray doesn't define __round__ method
# jab [[-0.43898487 -0.56626626 -0.39662659 -0.59812227]]
# Terjadi error: index 2 is out of bounds for axis 0 with size 1
# jab [[-0.24503235 -0.73383058 -0.16114039 -0.85999668]]
# Terjadi error: index 2 is out of bounds for axis 0 with size 1
# block [[-0.22846333 -0.71590444 -0.24478823 -0.810844  ]]
# Terjadi error: type numpy.ndarray doesn't define __round__ method
# block [[-0.25863089 -0.59873133 -0.28368923 -0.85894855]]
# Terjadi error: type numpy.ndarray doesn't define __round__ method
# jab [[-0.30577479 -0.58029373 -0.30501262 -0.80891886]]
# Terjadi error: index 2 is out of bounds for axis 0 with size 1
# block [[-0.25846478 -0.61742081 -0.32934186 -0.79477255]]
# Terjadi error: type numpy.ndarray doesn't define __round__ method
# cross [[-0.55053428  0.1598497  -0.1583476  -1.45096783]]
# Terjadi error: index 1 is out of bounds for axis 0 with size 1
# cross [[-0.50400262  0.04437025 -0.00495334 -1.53541429]]
# Terjadi error: index 1 is out of bounds for axis 0 with size 1
# cross [[-0.66902648  0.0342073  -0.02146008 -1.34372074]]
# Terjadi error: index 1 is out of bounds for axis 0 with size 1
# jab [[ 0.04369969 -0.85370438  0.4874519  -1.67744721]]
# Terjadi error: index 2 is out of bounds for axis 0 with size 1
# block [[ 0.49608091 -1.1264643   0.40597595 -1.77559256]]
# Terjadi error: type numpy.ndarray doesn't define __round__ method
# block [[ 1.53404936 -1.89454171  0.87847827 -2.51798592]]
# Terjadi error: type numpy.ndarray doesn't define __round__ method
# block [[ 1.86318201 -2.19615685  0.99587791 -2.66290306]]
# Terjadi error: type numpy.ndarray doesn't define __round__ method
# block [[ 2.75163494 -2.79339767  1.19730161 -3.15553888]]
# Terjadi error: type numpy.ndarray doesn't define __round__ method
# block [[ 3.07181291 -2.79899288  0.94048036 -3.21330039]]
# Terjadi error: type numpy.ndarray doesn't define __round__ method
# block [[ 3.91952183 -3.19265981  0.9236795  -3.65054152]]
# Terjadi error: type numpy.ndarray doesn't define __round__ method
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# block [[ 2.58739046 -1.54884413  0.75705555 -3.79560188]]
# Terjadi error: type numpy.ndarray doesn't define __round__ method
# block [[ 2.06776153 -1.25231499  0.786722   -3.60216854]]
# Terjadi error: type numpy.ndarray doesn't define __round__ method
# block [[ 1.69875979 -1.06135469  0.7556811  -3.39308619]]
# Terjadi error: type numpy.ndarray doesn't define __round__ method
# block [[ 1.32482709 -0.76566832  0.81846015 -3.37761892]]
# Terjadi error: type numpy.ndarray doesn't define __round__ method
# block [[ 1.03765736 -0.53837684  0.71060131 -3.20988183]]
# Terjadi error: type numpy.ndarray doesn't define __round__ method
# jab [[ 0.72047896 -0.42644139  0.79732783 -3.09136539]]
# Terjadi error: index 2 is out of bounds for axis 0 with size 1
# jab [[ 0.50663914 -0.19518341  0.69021178 -3.00166752]]
# Terjadi error: index 2 is out of bounds for axis 0 with size 1
# jab [[ 0.26677965 -0.08256868  0.59583204 -2.780043  ]]
# Terjadi error: index 2 is out of bounds for axis 0 with size 1
# jab [[ 0.09130719 -0.21161842  0.719467   -2.59915577]]
# Terjadi error: index 2 is out of bounds for axis 0 with size 1
# jab [[-0.05436111 -0.01559544  0.67264498 -2.60268844]]
# Terjadi error: index 2 is out of bounds for axis 0 with size 1
# jab [[-0.27499376  0.08742685  0.67552283 -2.48795592]]
# Terjadi error: index 2 is out of bounds for axis 0 with size 1
# jab [[-0.37233445  0.16594302  0.68781168 -2.48142024]]
# Terjadi error: index 2 is out of bounds for axis 0 with size 1
# jab [[-0.51575295  0.23565788  0.69756133 -2.41746625]]
# Terjadi error: index 2 is out of bounds for axis 0 with size 1
# jab [[-0.61043262  0.22565952  0.7794773  -2.3947042 ]]
# Terjadi error: index 2 is out of bounds for axis 0 with size 1
# jab [[-0.33687437 -0.68324099  0.24664885 -1.2265335 ]]
# Terjadi error: index 2 is out of bounds for axis 0 with size 1
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# uppercut [[-0.59360021 -0.76885711 -0.71396295  0.07642027]]
# Terjadi error: index 3 is out of bounds for axis 0 with size 1
# uppercut [[-0.78550612 -0.42320099 -0.96514719  0.17385429]]
# Terjadi error: index 3 is out of bounds for axis 0 with size 1
# uppercut [[-0.99725237 -0.26855601 -0.9369343   0.20274269]]
# Terjadi error: index 3 is out of bounds for axis 0 with size 1
# uppercut [[-0.8900822  -0.3259732  -0.88339242  0.09944781]]
# Terjadi error: index 3 is out of bounds for axis 0 with size 1
# uppercut [[-0.86248413 -0.26897495 -0.73077015 -0.13777077]]
# Terjadi error: index 3 is out of bounds for axis 0 with size 1
# cross [[-0.96604972 -0.08367737 -0.71933693 -0.23093598]]
# Terjadi error: index 1 is out of bounds for axis 0 with size 1
# uppercut [[-0.86212726 -0.25203747 -0.71638492 -0.16945035]]
# Terjadi error: index 3 is out of bounds for axis 0 with size 1
# cross [[-0.94620891  0.09211585 -0.92508931 -0.22081762]]
# Terjadi error: index 1 is out of bounds for axis 0 with size 1
# cross [[-0.9535343   0.01236019 -0.87567981 -0.18314608]]
# Terjadi error: index 1 is out of bounds for axis 0 with size 1
# cross [[-0.93141601 -0.06331709 -0.89106761 -0.11419929]]
# Terjadi error: index 1 is out of bounds for axis 0 with size 1
# cross [[-1.01882658e+00  1.79318979e-04 -8.93741665e-01 -8.76110765e-02]]
# Terjadi error: index 1 is out of bounds for axis 0 with size 1
# cross [[-1.13648294  0.03548521 -0.87824641 -0.02075586]]
# Terjadi error: index 1 is out of bounds for axis 0 with size 1
# cross [[-1.17200142  0.14500556 -0.91738347 -0.05562067]]
# Terjadi error: index 1 is out of bounds for axis 0 with size 1
# cross [[-0.90003724 -0.05552861 -0.88637888 -0.15805527]]
# Terjadi error: index 1 is out of bounds for axis 0 with size 1
# cross [[-1.77533902  1.35638388 -0.56297658 -1.01806827]]
# Terjadi error: index 1 is out of bounds for axis 0 with size 1
# cross [[-1.51836207  0.43651668 -0.38603766 -0.53211696]]
# Terjadi error: index 1 is out of bounds for axis 0 with size 1
# cross [[-1.22675022  0.03499066 -0.74253585 -0.06570459]]
# Terjadi error: index 1 is out of bounds for axis 0 with size 1
# uppercut [[-1.32699224 -0.15444267 -1.06597489  0.5474098 ]]
# Terjadi error: index 3 is out of bounds for axis 0 with size 1
# uppercut [[-1.11973528 -0.00651894 -1.08865852  0.21491274]]
# Terjadi error: index 3 is out of bounds for axis 0 with size 1
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# uppercut [[-1.16403571  0.21802019 -1.65866147  0.60467699]]
# Terjadi error: index 3 is out of bounds for axis 0 with size 1
# uppercut [[-1.06311284 -0.08658921 -1.60888627  0.75858832]]
# Terjadi error: index 3 is out of bounds for axis 0 with size 1
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# uppercut [[-0.57496982 -0.523703   -0.68329564 -0.21803153]]
# Terjadi error: index 3 is out of bounds for axis 0 with size 1
# uppercut [[-0.55729795 -0.53204942 -0.6943527  -0.21629993]]
# Terjadi error: index 3 is out of bounds for axis 0 with size 1
# block [[ 0.22429349 -0.96276658 -0.37537121 -0.8861557 ]]
# Terjadi error: type numpy.ndarray doesn't define __round__ method
# cross [[-1.17436758  0.38024368 -1.16033044 -0.04554565]]
# Terjadi error: index 1 is out of bounds for axis 0 with size 1
# cross [[-1.04354022  1.01559019 -0.36269456 -1.60935541]]
# Terjadi error: index 1 is out of bounds for axis 0 with size 1
# uppercut [[-0.31801908 -1.48826623 -1.19821199  1.00449731]]
# Terjadi error: index 3 is out of bounds for axis 0 with size 1
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# uppercut [[-1.25938313  0.25519403 -1.51972717  0.52391627]]
# Terjadi error: index 3 is out of bounds for axis 0 with size 1
# cross [[-0.98994315  0.82572457 -0.85247232 -0.9833091 ]]
# Terjadi error: index 1 is out of bounds for axis 0 with size 1
# uppercut [[-1.13197123  0.06240957 -1.1017059   0.17126756]]
# Terjadi error: index 3 is out of bounds for axis 0 with size 1
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# cross [[-0.26382693 -0.14151948 -0.32790201 -1.26675158]]
# Terjadi error: index 1 is out of bounds for axis 0 with size 1
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# uppercut [[-0.13794108 -1.08550192 -1.57489691  0.79833991]]
# Terjadi error: index 3 is out of bounds for axis 0 with size 1
# cross [[-0.47884087  0.18683133 -0.86304116 -0.8449493 ]]
# Terjadi error: index 1 is out of bounds for axis 0 with size 1
# uppercut [[-0.44912564 -0.47765165 -0.72273083 -0.35049189]]
# Terjadi error: index 3 is out of bounds for axis 0 with size 1
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# cross [[-0.49299094  0.07973072 -1.3699325  -0.21680729]]
# Terjadi error: index 1 is out of bounds for axis 0 with size 1
# block [[ 0.10421208 -0.47698774 -1.37060901 -0.25661533]]
# Terjadi error: type numpy.ndarray doesn't define __round__ method
# block [[ 0.18247136 -0.72831385 -1.26821754 -0.18593998]]
# Terjadi error: type numpy.ndarray doesn't define __round__ method
# Terjadi error: 'NoneType' object has no attribute 'landmark'
# uppercut [[ 0.27505084 -1.06873969 -1.81120944  0.60489829]]
# Terjadi error: index 3 is out of bounds for axis 0 with size 1
# Terjadi error: 'NoneType' object has no attribute 'landmark'

# %%
tuple(np.multiply(np.array((results.pose_landmarks.landmark[mp_holistic.PoseLandmark.LEFT_EAR].x, 
results.pose_landmarks.landmark[mp_holistic.PoseLandmark.LEFT_EAR].y)), [640,480]).astype(int))
# Out:
# (456, 195)
